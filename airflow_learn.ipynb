# %%
import pyodbc
import pandas as pd
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=192.168.0.105;DATABASE=test123;UID=sa_window;PWD=1234')


# )
myresult=pd.read_sql_query("select * from test.dbo.Fraud_Alert",conn)
conn.close()

myresult.head()
# Out:
# /tmp/ipykernel_4055/3303376300.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   myresult=pd.read_sql_query("select * from test.dbo.Fraud_Alert",conn)
#     session_id     Winner  Winning     Helper   Winner_User   Helper_User  \
# 0  114728735.0  4984707.0     37.4  5344311.0  jugaljodi353  jugaljodi353
# 1  114729005.0  6447469.0    127.5  6446845.0        Qm3OEY        7uOqHx
# 2  114729005.0  6447469.0    127.5  6446845.0        Qm3OEY        7uOqHx
# 3  114729151.0  5344311.0     37.4  4984707.0  jugaljodi353    kkaliya353
# 4  114729267.0  5344311.0    272.0  4984787.0  jugaljodi353     ombatra44
#
#   Wrong_Show Table_Left Dropped  Withdrawal_Request  ...       Fraud Found  \
# 0       None       None    None                 NaN  ...     Fraud Session
# ...

# %%
import pyodbc
import sqlalchemy as sal
from sqlalchemy import create_engine
import pandas as pd

# %%
import urllib
# params = urllib.parse.quote_plus("DRIVER={SQL Server Native Client 11.0};"
#                                  "SERVER=192.168.0.105;"
#                                  "DATABASE=test123;"
#                                  "UID=sa_window;"
#                                  "PWD=1234")

# engine = sa.create_engine("mssql+pyodbc:///?odbc_connect={}".format(params))

engine = sal.create_engine('mssql+pyodbc://192.168.0.105/test123?driver=SQL+Server+Native+Client+11.0',echo = True)

# %%
conn=engine.connect()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# File ~/Flask_Web/myFlaskApp/env/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File ~/Flask_Web/myFlaskApp/env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File ~/Flask_Web/myFlaskApp/env/lib/python3.10/site-packages/sqlalchemy/pool/base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# ...
